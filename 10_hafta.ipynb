# %% [markdown]
# <a href="https://colab.research.google.com/github/beratkc/Rprogramlama/blob/main/10_hafta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 10. hafta Fonksiyonlar
#R programlamada fonksiyon adi verilen yapilar yer alabilir
#Fonksiyon R programlarini moduler bir yapiya kavusturmak icin duzenlenen ve belirlenen
#bir gorevi yerine getiren program parcalaridir.
#fonksiyonlar programcinin tekrarlanan kodlar yazmasini onler
#fonksiyon belirli bir adi olan program parcalaridir.
#fonksiyonlar kullanim amaclarina gore iki turludur
#1kullanici tanimli
#2yerlesik hazir fonksiyonlar
#kullanici tanimli olani programci olusturmaktadir.


#Fonksiyonlarin Olusturulmasi
#fonksiyon adi <- function()
{
  #deyimler
}

#ornek
mesaj <- function()
{
  print("merhaba bilecik")
}

#daha once olusturulan fonksiyonun kodlarini gorelim
mesaj

#Fonksiyonlarin Calistirilmasi
mesaj() #[1] "merhaba bilecik"

sonuc <- function()
{
  print(3*pi/4)
}

sonuc()


#Bir Fonksiyondan Bir Baska Fonksiyonun Cagrilmasi
f <- function()
{
  mesajgoruntule()
}

mesajgoruntule <- function()
{
  print("merhaba bilecik")
}

f()

#Fonksiyon Calistiktan Sonra İslem Sirasi
#fonksiyon cagrildiktan sonra, bu fonksiyon islem gorur ve calismasi sona erdikten sonra
#islem sirasi yeniden onu cagiran programa ve bir sonraki satira gecer

#birinci fonksiyon
f <- function()
{
  mesajgoruntule()
  print("Merhaba R Dunyasi")
}

#ikinci fonksiyon
mesajgoruntule <- function()
{
  print("merhaba bilecik")
}
f()

#Fonksiyonun Degere Dondurmesi
#bu fonksiyon icinde deger alan bir degisken fonksiyon disinda bu degere sahiptir

sonuc <- function()
{
  x <-(3*pi/4)

}

hesapla <- sonuc()
hesapla


#
sonuc <- function()
{
  x <-(3*pi/4)
  print(x)
}
sonuc()


#ancak fonksiyon icinde tanimlanan degisken sayisi birden fazla ise
#en son degiskenin degerini dondurur


sonuc <- function()
{
  x<-(3*pi/4)
  y <- 55
  z <- 122
}

hesapla <- sonuc()
hesapla

sonuc <- function()
{
  x<-(3*pi/4)
  print(x)
  y <- 55
  print(y)
  z <- 122
  print(z)
}

sonuc()

sonuc1 <- function()
{
  cat(3*pi/4,"\n",55,"\n",122)
}

sonuc1()

#y ye donsurmek icin
sonuc <- function()
{
  x<-(3*pi/4)
  y <- 55
  z <- 122
  return(y)
}

hesapla <- sonuc()
hesapla

##
sonuc <- function()
{
  x<-(3*pi/4)
  y <- 55
  z <- 122
  return(x)
}

hesapla <- sonuc()
hesapla


#Liste Donusler
personelliste <- function()
{
  personel <-list("adi"="efe","boy"=183,"agirlik"=87)
  return(personel)
}

personelliste()
personelliste()[1]
personelliste()$adi
attach(personelliste())
adi
detach(personelliste())

#Fonksiyonlara Parametre Gecirme(fonksiyon cagirilirken fonksiyona bir degerin aktarilmasi)

#fonksiyonadi <- function(argumanlar)
{
  #deyimler
}

test <- function(x)
{if (is.numeric(x)==F){
  mesaj <- errorCondition("hata")
}
  else if(x>0){
    mesaj <- "pozitif sayi"
  }
  else if(x< 0) {
    mesaj <- "neagatif sayi"
  }
  else {
    mesaj <- "sifir"
  }
  return(mesaj)
}

test <- function(x)
{if (is.numeric(x)==F){
  errorCondition("hatalı giriş")
}else{

  if(x>0){
    mesaj <- "pozitif sayi"
  }
  else if(x< 0) {
    mesaj <- "neagatif sayi"
  }
  else {
    mesaj <- "sıfır"
  }
  return(mesaj)
}
}
test(-15)
test(10)
test(0)
test(10.5)

test("merhaba")
test("merhaba")

##ornek
dikdortgen <- function(a,b)
{
  alan<- a*b
  return(alan)
}

dikdortgen(4,5)
#####
dikdortgen <- function(a,b)
{
  return(a*b)
}

dikdortgen(2,5)

### faktoriyel
faktoriyel <- function(sayi)
{
  sonuc <- 1
  for(i in 1: sayi)
    sonuc <- sonuc*i
  return(sonuc)
}

faktoriyel(5)

#Kendini Cagiran Fonksiyonlar
faktoriyel <- function(sayi)
{
  if(sayi <=1) return(1)
  else return(sayi* faktoriyel(sayi-1))
}

faktoriyel(5)

faktoriyel(7)

#Yerlesik Hazir Fonksiyonlar
#MATEMATİK FONK
#acos ters cosinus
#asin ters sinus
#atan ters tanjant
#cos radyan olarak verilen acinin kosinusu
#cosh radyan olarak verilen acinin hiperbolik kosinusunu hesaplar
#sin radyan olarak verilen acinin sinusu
#sinh radyan olarak verilen acinin hiperbolik sinusu
#tan radyan olarak verilen acinin tanjanti
#tanh radyan oalrak verilen acinin hiperbolik tanjantı
#log bir sayisal degerin dogal logaritmasini hesaplar
#log10 bir sayisal degerin 10 tabanina gore logaritmasini hesaplar
#exp e nin belirli bir kuvvetini hesaplar
#abs bir degerin mutlak degerini hesaplar
#sqrt bir degerin karekokunun hesaplar
####TRİGONOMETRİK İSLEMLER
deger<-10
repeat
{
  derece<-3.14/180*deger
  cat("derece:",deger,"sin:",sin(derece),"\n")
  deger<-deger+10
  if(deger>90)break
}
#Logaritma islemleri
deger<-1
repeat
{
  cat("sayi:",deger,"Log:",log10(deger),"\n")
  deger<-deger+1
  if(deger>10)break
}
#E sayisinin kuvvetleri
deger<-1
repeat
{
  cat("us:",deger,"sonuc:",exp(deger),"\n")
  deger<-deger+1
  if(deger>10)break
}
#karekok islemleri
deger<-1
repeat
{
  cat("sayi:",deger,"karekok:",sqrt(deger),"\n")
  deger<-deger+1
  if(deger>10)break
}
#Mutlak deger
abs(-5)
x<-c(-12,25,0,36,-44,25)
abs(x)
#yuvarlatma islemleri
#round(kesirli sayi,hane sayisi)
x<-c(11.25,2.891,-4.0,5.251,7.3479)
round(x)
#iki haneli yuvarlama
x<-c(11.25,2.891,-4.0,5.251,7.3479)
round(x,2)
#ceiling() bir sayisal degeri yukaridan en yakin sayiya yuvarlatmak icin
x<-c(11.25,2.891,-4.0,5.251,7.3479)
ceiling(x)
#floor() asagidan en yakin tamsayiya yuvarlatmak icin
x<-c(11.25,2.891,-4.0,5.251,7.3479)
floor(x)
#kesme islemi
#trunc()
x<-c(11.25,2.891,-4.0,5.251,7.3479)
trunc(x)
#istatistik fonksiyonları
#mean() ortalama
#sd() standart sapma
#var() varyans
#median() medyan
#range() veri araligi
#sum() toplam
#min() minimum
#max() maximum
